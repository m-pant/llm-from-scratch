# %%
# 5.2 Training an LLM
from gpt_tools import calc_loss_batch, calc_loss_loader, text_to_token_ids, generate_text_simple,token_ids_to_text
from gpt_tools import GPTModel, GPTDatasetV1
import torch
import torch.utils.data as data
import tiktoken

def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    # Initialize lists to track losses and tokens seen
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen, global_step = 0, -1

    # Main training loop
    for epoch in range(num_epochs):
        model.train()  # Set model to training mode
        
        for input_batch, target_batch in train_loader:
            optimizer.zero_grad() # Reset loss gradients from previous batch iteration
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            loss.backward() # Calculate loss gradients
            optimizer.step() # Update model weights using loss gradients
            tokens_seen += input_batch.numel()
            global_step += 1

            # Optional evaluation step
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # Print a sample text after each epoch
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen


def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    model.eval()
    with torch.no_grad():
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
    model.train()
    return train_loss, val_loss


def generate_and_print_sample(model, tokenizer, device, start_context):
    model.eval()
    context_size = model.pos_emb.weight.shape[0]
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=10, context_size=context_size
        )
    decoded_text = token_ids_to_text(token_ids, tokenizer)
    print(decoded_text.replace("\n", " "))  # Compact print format
    model.train()

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

GPT_CONFIG_124M = {
    "vocab_size": 50257,
    "context_length": 256,
    "emb_dim": 768,
    "n_heads": 12,
    "n_layers": 12,
    "drop_rate": 0.1,
    "qkv_bias": False
}
tokenizer = tiktoken.get_encoding("gpt2")

# reading file
file_path = "the-verdict.txt"
with open(file_path, "r", encoding="utf-8") as file:
    text_data = file.read()


# printing stats
print("Characters:", len(text_data))
print("Tokens:", len(tokenizer.encode(text_data)))

# Crating Dataset
dataset = GPTDatasetV1(text_data, 
                       tokenizer, 
                       max_len=GPT_CONFIG_124M["context_length"], 
                       stride=GPT_CONFIG_124M["context_length"])
d_train, d_val = data.random_split(dataset , [0.9, 0.1])

train_loader  = data.DataLoader(d_train,batch_size=2, shuffle=True,drop_last=True)
val_loader  = data.DataLoader(d_val,batch_size=2, shuffle=False, drop_last=False)


torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=0.0004, weight_decay=0.1)

num_epochs = 100
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context="Every effort moves you", tokenizer=tokenizer
)
# Out:
# Characters: 20479
# Tokens: 5145
# Ep 1 (Step 000000): Train loss 9.817, Val loss 10.080
# Ep 1 (Step 000005): Train loss 7.994, Val loss 8.632
# tensor([6109, 3626, 6100,  345,  262,  262,  262,  262,  262,  262,  262,  262,
#          262,  262], device='cuda:0')
# Every effort moves you the the the the the the the the the the
# Ep 2 (Step 000010): Train loss 6.561, Val loss 7.685
# Ep 2 (Step 000015): Train loss 6.065, Val loss 7.487
# tensor([6109, 3626, 6100,  345,  262,    1,  198,  198,  198,  198,  198,  198,
#          198,  198], device='cuda:0')
# Every effort moves you the"
# Ep 3 (Step 000020): Train loss 5.520, Val loss 7.392
# Ep 3 (Step 000025): Train loss 5.477, Val loss 7.429
# tensor([6109, 3626, 6100,  345,  760,  198,  198,  198,  198,  198,  198,  198,
#          198,  198], device='cuda:0')
# Every effort moves you know
# Ep 4 (Step 000030): Train loss 5.202, Val loss 7.503
# Ep 4 (Step 000035): Train loss 4.949, Val loss 7.408
# tensor([6109, 3626, 6100,  345,  760,  284,  423,  257,    1,   40,  257,  438,
#           40,  438], device='cuda:0')
# Every effort moves you know to have a"I a--I--
# Ep 5 (Step 000040): Train loss 4.375, Val loss 7.446
# tensor([6109, 3626, 6100,  345,  760,  198,  198,  198,  198,  198,  198,  198,
#          198,  198], device='cuda:0')
# Every effort moves you know
# Ep 6 (Step 000045): Train loss 4.078, Val loss 7.192
# Ep 6 (Step 000050): Train loss 3.665, Val loss 7.194
# tensor([6109, 3626, 6100,  345,  760,  198,  198,  198,  198,  198,  198,  198,
#          198,  198], device='cuda:0')
# Every effort moves you know
# Ep 7 (Step 000055): Train loss 3.736, Val loss 7.236
# Ep 7 (Step 000060): Train loss 2.931, Val loss 7.280
# tensor([6109, 3626, 6100,  345,  760,  198,  198,  198,  198,  198,  198,  198,
#            1,   40], device='cuda:0')
# Every effort moves you know       "I
# Ep 8 (Step 000065): Train loss 2.535, Val loss 7.225
# Ep 8 (Step 000070): Train loss 2.165, Val loss 7.254
# tensor([6109, 3626, 6100,  345,  760,  810,  284,  616, 5975,   13,  198,    1,
#           40, 1422], device='cuda:0')
# Every effort moves you know where to my surprise. "I didn
# Ep 9 (Step 000075): Train loss 1.795, Val loss 7.318
# Ep 9 (Step 000080): Train loss 1.484, Val loss 7.371
# tensor([6109, 3626, 6100,  345,  760,  810,  284,  467,  257, 1310, 4295,  438,
#           40, 1422], device='cuda:0')
# Every effort moves you know where to go a little wild--I didn
# Ep 10 (Step 000085): Train loss 1.171, Val loss 7.392
# tensor([6109, 3626, 6100,  345,  760,  553,  373,  530,  286,  262, 4286,  329,
#         2147,  438], device='cuda:0')
# Every effort moves you know," was one of the picture for nothing--
# Ep 11 (Step 000090): Train loss 0.870, Val loss 7.444
# Ep 11 (Step 000095): Train loss 0.756, Val loss 7.532
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 12 (Step 000100): Train loss 0.547, Val loss 7.534
# Ep 12 (Step 000105): Train loss 0.376, Val loss 7.611
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 13 (Step 000110): Train loss 0.295, Val loss 7.697
# Ep 13 (Step 000115): Train loss 0.268, Val loss 7.792
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,   198,   198,   198,
#            40, 27846,   706,   683], device='cuda:0')
# Every effort moves you?"     I glanced after him
# Ep 14 (Step 000120): Train loss 0.230, Val loss 7.919
# Ep 14 (Step 000125): Train loss 0.185, Val loss 7.898
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 15 (Step 000130): Train loss 0.119, Val loss 7.964
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,   198,   198,   198,
#            40, 27846,   706,   683], device='cuda:0')
# Every effort moves you?"     I glanced after him
# Ep 16 (Step 000135): Train loss 0.193, Val loss 8.061
# Ep 16 (Step 000140): Train loss 0.144, Val loss 8.104
# tensor([ 6109,  3626,  6100,   345,  1701,   198,     1,    40,    12,  5532,
#         14000,    13,   198,     1], device='cuda:0')
# Every effort moves you?" "I-stream stroke. "
# Ep 17 (Step 000145): Train loss 0.122, Val loss 8.053
# Ep 17 (Step 000150): Train loss 0.111, Val loss 8.148
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 18 (Step 000155): Train loss 0.102, Val loss 8.071
# Ep 18 (Step 000160): Train loss 0.071, Val loss 8.114
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 19 (Step 000165): Train loss 0.069, Val loss 8.199
# Ep 19 (Step 000170): Train loss 0.069, Val loss 8.166
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 20 (Step 000175): Train loss 0.057, Val loss 8.218
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 21 (Step 000180): Train loss 0.044, Val loss 8.233
# Ep 21 (Step 000185): Train loss 0.036, Val loss 8.290
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 22 (Step 000190): Train loss 0.035, Val loss 8.295
# Ep 22 (Step 000195): Train loss 0.039, Val loss 8.365
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 23 (Step 000200): Train loss 0.037, Val loss 8.229
# Ep 23 (Step 000205): Train loss 0.023, Val loss 8.302
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 24 (Step 000210): Train loss 0.028, Val loss 8.386
# Ep 24 (Step 000215): Train loss 0.021, Val loss 8.359
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 25 (Step 000220): Train loss 0.024, Val loss 8.411
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 26 (Step 000225): Train loss 0.019, Val loss 8.492
# Ep 26 (Step 000230): Train loss 0.020, Val loss 8.433
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 27 (Step 000235): Train loss 0.014, Val loss 8.440
# Ep 27 (Step 000240): Train loss 0.013, Val loss 8.503
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 28 (Step 000245): Train loss 0.016, Val loss 8.550
# Ep 28 (Step 000250): Train loss 0.010, Val loss 8.509
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 29 (Step 000255): Train loss 0.014, Val loss 8.520
# Ep 29 (Step 000260): Train loss 0.011, Val loss 8.500
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 30 (Step 000265): Train loss 0.011, Val loss 8.516
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 31 (Step 000270): Train loss 0.008, Val loss 8.581
# Ep 31 (Step 000275): Train loss 0.007, Val loss 8.598
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 32 (Step 000280): Train loss 0.008, Val loss 8.582
# Ep 32 (Step 000285): Train loss 0.008, Val loss 8.575
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 33 (Step 000290): Train loss 0.007, Val loss 8.597
# Ep 33 (Step 000295): Train loss 0.006, Val loss 8.624
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 34 (Step 000300): Train loss 0.006, Val loss 8.627
# Ep 34 (Step 000305): Train loss 0.007, Val loss 8.643
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 35 (Step 000310): Train loss 0.005, Val loss 8.654
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 36 (Step 000315): Train loss 0.007, Val loss 8.640
# Ep 36 (Step 000320): Train loss 0.005, Val loss 8.631
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 37 (Step 000325): Train loss 0.005, Val loss 8.643
# Ep 37 (Step 000330): Train loss 0.004, Val loss 8.668
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 38 (Step 000335): Train loss 0.004, Val loss 8.698
# Ep 38 (Step 000340): Train loss 0.003, Val loss 8.704
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 39 (Step 000345): Train loss 0.003, Val loss 8.702
# Ep 39 (Step 000350): Train loss 0.005, Val loss 8.698
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 40 (Step 000355): Train loss 0.003, Val loss 8.699
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 41 (Step 000360): Train loss 0.004, Val loss 8.730
# Ep 41 (Step 000365): Train loss 0.003, Val loss 8.768
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 42 (Step 000370): Train loss 0.005, Val loss 8.758
# Ep 42 (Step 000375): Train loss 0.006, Val loss 8.756
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 43 (Step 000380): Train loss 0.003, Val loss 8.760
# Ep 43 (Step 000385): Train loss 0.003, Val loss 8.772
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 44 (Step 000390): Train loss 0.009, Val loss 8.801
# Ep 44 (Step 000395): Train loss 0.012, Val loss 8.751
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 45 (Step 000400): Train loss 0.004, Val loss 8.730
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 46 (Step 000405): Train loss 0.003, Val loss 8.727
# Ep 46 (Step 000410): Train loss 0.003, Val loss 8.810
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 47 (Step 000415): Train loss 0.004, Val loss 8.810
# Ep 47 (Step 000420): Train loss 0.005, Val loss 8.834
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 48 (Step 000425): Train loss 0.002, Val loss 8.795
# Ep 48 (Step 000430): Train loss 0.003, Val loss 8.786
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 49 (Step 000435): Train loss 0.003, Val loss 8.784
# Ep 49 (Step 000440): Train loss 0.004, Val loss 8.775
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 50 (Step 000445): Train loss 0.003, Val loss 8.816
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 51 (Step 000450): Train loss 0.002, Val loss 8.777
# Ep 51 (Step 000455): Train loss 0.003, Val loss 8.739
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 52 (Step 000460): Train loss 0.004, Val loss 8.763
# Ep 52 (Step 000465): Train loss 0.007, Val loss 8.776
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 53 (Step 000470): Train loss 0.002, Val loss 8.783
# Ep 53 (Step 000475): Train loss 0.005, Val loss 8.814
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 54 (Step 000480): Train loss 0.006, Val loss 8.788
# Ep 54 (Step 000485): Train loss 0.005, Val loss 8.800
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 55 (Step 000490): Train loss 0.008, Val loss 8.897
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 56 (Step 000495): Train loss 0.002, Val loss 8.822
# Ep 56 (Step 000500): Train loss 0.005, Val loss 8.847
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 57 (Step 000505): Train loss 0.006, Val loss 8.821
# Ep 57 (Step 000510): Train loss 0.015, Val loss 8.885
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 58 (Step 000515): Train loss 0.019, Val loss 8.851
# Ep 58 (Step 000520): Train loss 0.009, Val loss 8.743
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 59 (Step 000525): Train loss 0.012, Val loss 8.796
# Ep 59 (Step 000530): Train loss 0.007, Val loss 8.765
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 60 (Step 000535): Train loss 0.008, Val loss 8.857
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 61 (Step 000540): Train loss 0.008, Val loss 8.812
# Ep 61 (Step 000545): Train loss 0.011, Val loss 8.800
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 62 (Step 000550): Train loss 0.011, Val loss 9.023
# Ep 62 (Step 000555): Train loss 0.013, Val loss 8.813
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 63 (Step 000560): Train loss 0.017, Val loss 8.713
# Ep 63 (Step 000565): Train loss 0.029, Val loss 8.785
# tensor([ 6109,  3626,  6100,   345,  1701,   198,  1544,  6204,    12,  5532,
#         14000,    13,   679,  1422], device='cuda:0')
# Every effort moves you?" He stood-stream stroke. He didn
# Ep 64 (Step 000570): Train loss 0.010, Val loss 8.804
# Ep 64 (Step 000575): Train loss 0.009, Val loss 8.859
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 65 (Step 000580): Train loss 0.017, Val loss 8.776
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 66 (Step 000585): Train loss 0.008, Val loss 8.834
# Ep 66 (Step 000590): Train loss 0.017, Val loss 8.766
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 67 (Step 000595): Train loss 0.017, Val loss 8.728
# Ep 67 (Step 000600): Train loss 0.024, Val loss 8.755
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 68 (Step 000605): Train loss 0.019, Val loss 8.926
# Ep 68 (Step 000610): Train loss 0.017, Val loss 8.823
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 69 (Step 000615): Train loss 0.029, Val loss 8.795
# Ep 69 (Step 000620): Train loss 0.022, Val loss 8.853
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 70 (Step 000625): Train loss 0.009, Val loss 8.846
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 71 (Step 000630): Train loss 0.016, Val loss 8.836
# Ep 71 (Step 000635): Train loss 0.013, Val loss 8.922
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 72 (Step 000640): Train loss 0.012, Val loss 9.009
# Ep 72 (Step 000645): Train loss 0.026, Val loss 8.962
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 73 (Step 000650): Train loss 0.050, Val loss 8.937
# Ep 73 (Step 000655): Train loss 0.032, Val loss 8.899
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 74 (Step 000660): Train loss 0.030, Val loss 8.959
# Ep 74 (Step 000665): Train loss 0.026, Val loss 8.878
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 75 (Step 000670): Train loss 0.023, Val loss 8.873
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 76 (Step 000675): Train loss 0.019, Val loss 8.904
# Ep 76 (Step 000680): Train loss 0.016, Val loss 8.801
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 77 (Step 000685): Train loss 0.015, Val loss 8.806
# Ep 77 (Step 000690): Train loss 0.015, Val loss 8.814
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 78 (Step 000695): Train loss 0.012, Val loss 8.737
# Ep 78 (Step 000700): Train loss 0.012, Val loss 8.855
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 79 (Step 000705): Train loss 0.010, Val loss 8.894
# Ep 79 (Step 000710): Train loss 0.008, Val loss 8.812
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 80 (Step 000715): Train loss 0.006, Val loss 8.834
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 81 (Step 000720): Train loss 0.006, Val loss 8.902
# Ep 81 (Step 000725): Train loss 0.006, Val loss 8.895
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 82 (Step 000730): Train loss 0.005, Val loss 8.871
# Ep 82 (Step 000735): Train loss 0.003, Val loss 8.894
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 83 (Step 000740): Train loss 0.002, Val loss 8.929
# Ep 83 (Step 000745): Train loss 0.002, Val loss 8.954
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 84 (Step 000750): Train loss 0.001, Val loss 8.933
# Ep 84 (Step 000755): Train loss 0.001, Val loss 8.915
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 85 (Step 000760): Train loss 0.001, Val loss 8.915
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 86 (Step 000765): Train loss 0.001, Val loss 8.930
# Ep 86 (Step 000770): Train loss 0.001, Val loss 8.953
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 87 (Step 000775): Train loss 0.001, Val loss 8.976
# Ep 87 (Step 000780): Train loss 0.001, Val loss 8.992
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 88 (Step 000785): Train loss 0.001, Val loss 9.000
# Ep 88 (Step 000790): Train loss 0.001, Val loss 8.997
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 89 (Step 000795): Train loss 0.001, Val loss 8.991
# Ep 89 (Step 000800): Train loss 0.001, Val loss 8.991
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 90 (Step 000805): Train loss 0.001, Val loss 9.001
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 91 (Step 000810): Train loss 0.001, Val loss 9.021
# Ep 91 (Step 000815): Train loss 0.001, Val loss 9.040
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 92 (Step 000820): Train loss 0.001, Val loss 9.048
# Ep 92 (Step 000825): Train loss 0.001, Val loss 9.047
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 93 (Step 000830): Train loss 0.001, Val loss 9.046
# Ep 93 (Step 000835): Train loss 0.001, Val loss 9.044
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 94 (Step 000840): Train loss 0.001, Val loss 9.044
# Ep 94 (Step 000845): Train loss 0.001, Val loss 9.047
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 95 (Step 000850): Train loss 0.001, Val loss 9.053
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 96 (Step 000855): Train loss 0.001, Val loss 9.057
# Ep 96 (Step 000860): Train loss 0.001, Val loss 9.060
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 97 (Step 000865): Train loss 0.001, Val loss 9.062
# Ep 97 (Step 000870): Train loss 0.001, Val loss 9.064
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 98 (Step 000875): Train loss 0.001, Val loss 9.067
# Ep 98 (Step 000880): Train loss 0.001, Val loss 9.069
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 99 (Step 000885): Train loss 0.001, Val loss 9.072
# Ep 99 (Step 000890): Train loss 0.001, Val loss 9.076
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to
# Ep 100 (Step 000895): Train loss 0.001, Val loss 9.079
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284], device='cuda:0')
# Every effort moves you?"  "Yes--quite insensible to

# %%
import matplotlib.pyplot as plt
import os
os.environ['KMP_DUPLICATE_LIB_OK'] = 'TRUE'
from matplotlib.ticker import MaxNLocator


def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    fig, ax1 = plt.subplots(figsize=(5, 3))

    # Plot training and validation loss against epochs
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")
    ax1.xaxis.set_major_locator(MaxNLocator(integer=True))  # only show integer labels on x-axis

    # Create a second x-axis for tokens seen
    ax2 = ax1.twiny()  # Create a second x-axis that shares the same y-axis
    ax2.plot(tokens_seen, train_losses, alpha=0)  # Invisible plot for aligning ticks
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout()  # Adjust layout to make room
    plt.savefig("loss-plot.pdf")
    plt.show()

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)

# %%
# NEW: use CPU here as inference is cheap with 
# this model and to ensure readers get same results in the
# remaining sections of this book
inference_device = torch.device("cpu")

model.to(inference_device)
model.eval()

tokenizer = tiktoken.get_encoding("gpt2")

token_ids = generate_text_simple(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(inference_device),
    max_new_tokens=25,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284,   262, 21296,    13,  1375,  2227,   683,
#         29178,  3474,   438,   392,   416,   502,  2474,   198,   198])
# Output text:
#  Every effort moves you?"
#
# "Yes--quite insensible to the irony. She wanted him vindicated--and by me!"

# %%
# 5.3.1 Temperature scaling
vocab = { 
    "closer": 0,
    "every": 1, 
    "effort": 2, 
    "forward": 3,
    "inches": 4,
    "moves": 5, 
    "pizza": 6,
    "toward": 7,
    "you": 8,
} 

inverse_vocab = {v: k for k, v in vocab.items()}

# Suppose input is "every effort moves you", and the LLM
# returns the following logits for the next token:
next_token_logits = torch.tensor(
    [4.51, 0.89, -1.90, 6.75, 1.63, -1.62, -1.89, 6.28, 1.79]
)

probas = torch.softmax(next_token_logits, dim=0)

# Option 1, simply select max prob
next_token_id = torch.argmax(probas).item()
print(inverse_vocab[next_token_id])

# Option 2, using mulinomal to implement a probabilistic sampling proces
torch.manual_seed(123)
next_token_id = torch.multinomial(probas, num_samples=1).item()
print(inverse_vocab[next_token_id])

# But this result is thhe resul of most prob word that we meet
def print_sampled_tokens(probas):
    torch.manual_seed(123) # Manual seed for reproducibility
    sample = [torch.multinomial(probas, num_samples=1).item() for i in range(1_000)]
    sampled_ids = torch.bincount(torch.tensor(sample), minlength=len(probas))
    for i, freq in enumerate(sampled_ids):
        print(f"{freq} x {inverse_vocab[i]}")

print_sampled_tokens(probas)
# Out:
# forward
# forward
# 73 x closer
# 0 x every
# 0 x effort
# 582 x forward
# 2 x inches
# 0 x moves
# 0 x pizza
# 343 x toward
# 0 x you

# %%
# To control distrubution we implementing function with temperature
def softmax_with_temperature(logits, temperature):
    scaled_logits = logits / temperature
    return torch.softmax(scaled_logits, dim=0)

# Temperature values
temperatures = [1, 0.1, 5]  # Original, higher confidence, and lower confidence

# Calculate scaled probabilities
scaled_probas = [softmax_with_temperature(next_token_logits, T) for T in temperatures]

# Plotting
x = torch.arange(len(vocab))
bar_width = 0.15

fig, ax = plt.subplots(figsize=(5, 3))
for i, T in enumerate(temperatures):
    rects = ax.bar(x + i * bar_width, scaled_probas[i], bar_width, label=f'Temperature = {T}')

ax.set_ylabel('Probability')
ax.set_xticks(x)
ax.set_xticklabels(vocab.keys(), rotation=90)
ax.legend()

plt.tight_layout()
plt.savefig("temperature-plot.pdf")
plt.show()

# %%
# Finally, we applying with different temp ( T - highter, system is more chaotic, T - lower system more stable)

for T in temperatures:
    # Calculate scaled probabilities
    scaled_probas = softmax_with_temperature(next_token_logits, T)
    next_token_id = torch.multinomial(scaled_probas, num_samples=1).item()
    print(inverse_vocab[next_token_id])
# Out:
# toward
# forward
# closer

# %%
# 5.3.2 Top-k sampling
top_k = 3
top_logits, top_pos = torch.topk(next_token_logits, top_k)

print("Top logits:", top_logits)
print("Top positions:", top_pos)

new_logits = torch.where(
    condition=next_token_logits < top_logits[-1],
    input=torch.tensor(float("-inf")), 
    other=next_token_logits
)

print(new_logits)

topk_probas = torch.softmax(new_logits, dim=0)
print(topk_probas)
# Out:
# Top logits: tensor([6.7500, 6.2800, 4.5100])
# Top positions: tensor([3, 7, 0])
# tensor([4.5100,   -inf,   -inf, 6.7500,   -inf,   -inf,   -inf, 6.2800,   -inf])
# tensor([0.0615, 0.0000, 0.0000, 0.5775, 0.0000, 0.0000, 0.0000, 0.3610, 0.0000])

# %%
# 5.3.3 Modifying the text generation function
def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):

    # For-loop is the same as before: Get logits, and only focus on last time step
    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        with torch.no_grad():
            logits = model(idx_cond)
        logits = logits[:, -1, :]

        # New: Filter logits with top_k sampling
        if top_k is not None:
            # Keep only top_k values
            top_logits, _ = torch.topk(logits, top_k)
            min_val = top_logits[:, -1]
            logits = torch.where(logits < min_val, torch.tensor(float("-inf")).to(logits.device), logits)

        # New: Apply temperature scaling
        if temperature > 0.0:
            logits = logits / temperature

            # New (not in book): numerical stability tip to get equivalent results on mps device
            # subtract rowwise max before softmax
            logits = logits - logits.max(dim=-1, keepdim=True).values
            
            # Apply softmax to get probabilities
            probs = torch.softmax(logits, dim=-1)  # (batch_size, context_len)

            # Sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1)  # (batch_size, 1)

        # Otherwise same as before: get idx of the vocab entry with the highest logits value
        else:
            idx_next = torch.argmax(logits, dim=-1, keepdim=True)  # (batch_size, 1)

        if idx_next == eos_id:  # Stop generating early if end-of-sequence token is encountered and eos_id is specified
            break

        # Same as before: append sampled index to the running sequence
        idx = torch.cat((idx, idx_next), dim=1)  # (batch_size, num_tokens+1)

    return idx

torch.manual_seed(123)

token_ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(inference_device),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=25,
    temperature=1.4
)

print("Output text:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# tensor([ 6109,  3626,  6100,   345,  1701,   198,   198,     1,  5297,   438,
#         37121,  1035, 27339,   284,   262, 18560,    13,  1375,  2227])
# Output text:
#  Every effort moves you?"
#
# "Yes--quite insensible to the portrait. She wanted
